# %%
import numpy as np 
import pyproffit
import matplotlib.pyplot as plt
import h5py
import astropy.io as fits

from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS

from astropy.convolution import Gaussian2DKernel
from astropy.modeling.models import Lorentz1D
from astropy.convolution import convolve_fft

# %matplotlib inline

# %%
h5_file_halo = 'grid_halo_TNG100-1_99_111.hdf5'
fits_file_halo = 'grid_halo_TNG100-1_99_111.fits'

# %%
with h5py.File(h5_file_halo, 'r+') as f:
    print("Keys: %s" % f.keys())
    # Get the data
    grid_data = f['grid'][...]
    print(grid_data)
    header_data = f['Header']
    #print(data)
# Out:
# Keys: <KeysViewHDF5 ['Header', 'grid']>
# [[99. 99. 99. ... 99. 99. 99.]
#  [99. 99. 99. ... 99. 99. 99.]
#  [99. 99. 99. ... 99. 99. 99.]
#  ...
#  [99. 99. 99. ... 99. 99. 99.]
#  [99. 99. 99. ... 99. 99. 99.]
#  [99. 99. 99. ... 99. 99. 99.]]

# %%
with h5py.File(h5_file_halo, 'r') as f:
    data = f['grid'][()]
    hdu = fits.PrimaryHDU(data)
    hdu.writeto(fits_file_halo, overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 with h5py.File(h5_file_halo, 'r') as f:
#       2     data = f['grid'][()]
# ----> 3     hdu = fits.PrimaryHDU(data)
#       4     hdu.writeto(fits_file_halo, overwrite=True)
#
# AttributeError: module 'astropy.io' has no attribute 'PrimaryHDU'

# %%
fits
# Out:
# Type:        module
# String form: <module 'astropy.io' from '/opt/homebrew/anaconda3/envs/astro/lib/python3.13/site-packages/astropy/io/__init__.py'>
# File:        /opt/homebrew/anaconda3/envs/astro/lib/python3.13/site-packages/astropy/io/__init__.py
# Docstring:
# This subpackage contains modules and packages for interpreting data storage
# formats used by and in astropy.
