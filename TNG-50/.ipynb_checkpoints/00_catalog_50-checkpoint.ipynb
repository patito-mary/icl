# %%
import illustris_python as il
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('..')
import h5py

from astropy.cosmology import FlatLambdaCDM
import params_icl_50 as P
import simulation_physical_improves as spi


# %matplotlib inline
plt.rcParams.update({'figure.figsize': (10, 6), 
              'figure.dpi': 150,
              'font.size': 14,
              'font.family': 'serif',
              'axes.labelsize': 14})

cosmo = FlatLambdaCDM(H0=P.H0, Om0=P.Om0)
h = P.H0/100

# %% [markdown]
# ## catalogo de halos masivos

# %%
fields_halos = P.HALOS_FIELDS
fields_subhalos = P.SUBHALOS_FIELDS

# %%
subhalos = il.groupcat.loadSubhalos(P.basePath, P.SNAP, fields_subhalos) 
subhalos['SubfindID'] = np.arange(subhalos['SubhaloMassType'][:, 4].shape[0])

stellar_masses_subhalos = np.log10(subhalos['SubhaloMassType'][:, 4]/h) + 10
flag_subhalos = subhalos['SubhaloFlag'] == 1

valid_subhalos = stellar_masses_subhalos >= 9.5

#valid_subhalos = subhalos['SubhaloMassType'][stellar_subhalos > 9.5]
# Out:
# /tmp/ipykernel_12708/446849245.py:4: RuntimeWarning: divide by zero encountered in log10
#   stellar_masses_subhalos = np.log10(subhalos['SubhaloMassType'][:, 4]/h) + 10

# %%
halos = il.groupcat.loadHalos(P.basePath, P.SNAP, fields_halos)
halos['HaloID'] = np.arange(halos['Group_M_Crit200'].shape[0])

masses_halos = np.log10(halos['Group_M_Crit200']/h) + 10
valid_halos = masses_halos >= 13
# Out:
# /tmp/ipykernel_12708/2381461734.py:4: RuntimeWarning: divide by zero encountered in log10
#   masses_halos = np.log10(halos['Group_M_Crit200']/h) + 10

# %%
subhalos_tree = il.groupcat.loadSubhalos(P.basePath, P.SNAP, fields_subhalos)
halos_tree = il.groupcat.loadHalos(P.basePath, P.SNAP, fields_halos)

# %%
# catalog cookin
F05R200, F05R200_deltamags, F05_distance, F05_mass, F05_radius, F05_sats = [], [], [], [], [], []
NF05R200, NF05R200_deltamags, NF05_distance, NF05_mass, NF05_radius, NF05_sats = [], [], [], [], [], []

F1R200, F1R200_deltamags, F1_distance, F1_mass, F1_radius, F1_sats = [], [], [], [], [], []
NF1R200, NF1R200_deltamags, NF1_distance, NF1_mass, NF1_radius, NF1_sats = [], [], [], [], [], []

iso_fossil_05, iso_F05_mass, iso_F05_radius, iso_F05_sats = [], [], [], []
iso_fossil_1, iso_F1_mass, iso_F1_radius, iso_F1_sats = [], [], [], []

# %%
# conditions to separate the sample 

stellar_mass = np.log10(subhalos['SubhaloMassType'][:, 4]/h) + 10
pos = subhalos_tree['SubhaloPos'][:]/h
R200 = halos_tree['Group_R_Crit200'][:]/h
M200 = np.log10(halos_tree['Group_M_Crit200'][:]/h) + 10
mag_r = subhalos['SubhaloStellarPhotometrics'][:, 5]
cens =  halos_tree['GroupFirstSub'][:]
subhalos_GrNr = subhalos_tree['SubhaloGrNr'][:]
ID_subhalos = subhalos['SubfindID']
#satellites with mass threshold: 
#ID_mass_treshold = subhalos['SubfindID'][valid_subhalos])]
# Out:
# /tmp/ipykernel_12708/3035896826.py:3: RuntimeWarning: divide by zero encountered in log10
#   stellar_mass = np.log10(subhalos['SubhaloMassType'][:, 4]/h) + 10
# /tmp/ipykernel_12708/3035896826.py:6: RuntimeWarning: divide by zero encountered in log10
#   M200 = np.log10(halos_tree['Group_M_Crit200'][:]/h) + 10

# %%
for group in halos['HaloID'][valid_halos]:
#    group = halos['HaloID'][valid_halos]
    central = cens[group]
    
    print(f'len(valid_halos) = {len(valid_halos)}')
    print(f'valid_halos.dtype = {valid_halos.dtype}')   # bool vs int
    print(f'len(halos["HaloID"][valid_halos]) = {len(halos["HaloID"][valid_halos])}')
    
    tree_first = il.sublink.loadTree(P.basePath, P.SNAP, id=central, fields=['SubfindID', 'SnapNum'], onlyMPB=True)
    
    halo_check = subhalos_GrNr[tree_first['SubfindID'][0]]
    
    if central != cens[halo_check]:
        print('halo mismatch')
        continue
    print(halo_check)
    
    # stellar mass cut
    gals = np.where((subhalos_GrNr == group) & (stellar_mass >= 9.5))[0]
    
    central_pos = pos[central]
    r200_halo = R200[halo_check]
    m200_group = M200[group]
    #r200_group = R200[group]
    
    xc = spi.Distance_1D(pos[gals, 0], central_pos[0], (35000/h))
    yc = spi.Distance_1D(pos[gals, 1], central_pos[1], (35000/h))
    zc = spi.Distance_1D(pos[gals, 2], central_pos[2], (35000/h))
    normpos = np.sqrt(xc**2 + yc**2 + zc**2)/r200_halo
    
    #print(xc, yc, zc)
    #print(normpos)
    #print(r200_halo)
    #print(central_pos)
    #print(gals)
    
    print('-halo: ', group, '\n -central: ', central, '\n -stellar mass: ', stellar_mass[central], '\n -r200: ', r200_halo, '\n -m200: ', m200_group)
    
    mags_all = subhalos_tree['SubhaloStellarPhotometrics'][gals, 5]
    central_galaxy = np.where(normpos == 0)[0]
    central_mag = mags_all[central_galaxy]
    
    for r_frac, F_lists, NF_lists, iso_list, iso_mass, iso_radius in zip(
        [0.5, 1.0],
        [(F05R200, F05R200_deltamags, F05_distance, F05_mass, F05_radius, F05_sats),
         (F1R200,   F1R200_deltamags,   F1_distance,  F1_mass,  F1_radius,  F1_sats)],
        [(NF05R200, NF05R200_deltamags, NF05_distance, NF05_mass, NF05_radius, NF05_sats),
         (NF1R200,   NF1R200_deltamags,   NF1_distance,  NF1_mass,  NF1_radius,  NF1_sats)],
        [iso_fossil_05, iso_fossil_1],
        [iso_F05_mass,  iso_F1_mass],
    [iso_F05_radius, iso_F1_radius]):
            if not spi.classify_fossil(group, mags_all, central_mag, normpos, gals,
                            m200_group, r200_halo, F_lists, NF_lists,
                            r_frac=r_frac):
                print(f'El grupo {group} solo tiene una galaxia central dentro de {r_frac} R200')
                iso_list.append(group)
                iso_mass.append(m200_group)
                iso_radius.append(r200_halo)
# Out:
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 0
# -halo:  0
#  -central:  0
#  -stellar mass:  12.735348
#  -r200:  1198.2006
#  -m200:  14.263622
# 4.578296661376953
# Group 0 classified as fossil with gap 4.58 and R/R200 [0.46568605 0.36581042 0.05397549 0.3567919  0.15013972 0.36963913
#  0.4197074  0.03299361 0.40739873 0.4589882  0.4125978  0.11105671
#  0.4555248  0.22797297 0.33783442 0.1319174  0.41726932 0.12922563
#  0.3923941  0.26096955 0.373793   0.2175347  0.09547936 0.03111966
#  0.2655455  0.2613965  0.12380687 0.32762817 0.07018632 0.47548392
#  0.3729942  0.06243182 0.03838016 0.13315746 0.1380067  0.08390512
#  0.14499633 0.09937399 0.0896776  0.13620627 0.0955207  0.14062905]

# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 4
# -halo:  4
#  -central:  143880
#  -stellar mass:  11.508397
#  -r200:  671.18726
#  -m200:  13.508556
# 0.7524147033691406
# Group 4 classified as non-fossil with gap 0.75 and R/R200 [0.39918596 0.11892518 0.43162873 0.36773333]
# 0.7524147033691406
# Group 4 classified as non-fossil with gap 0.75 and R/R200 [0.9380977  0.39918596 0.11892518 0.8327377  0.6286454  0.75431496
#  0.43162873 0.8790648  0.36773333 0.60799533 0.82462525]
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 5
# -halo:  5
#  -central:  167392
#  -stellar mass:  11.744446
#  -r200:  583.2861
#  -m200:  13.325664
# 2.8388748168945312
# Group 5 classified as fossil with gap 2.84 and R/R200 [0.20708148 0.22804098 0.37040058 0.0565076  0.09960289 0.04799042]
# 1.2794780731201172
# Group 5 classified as non-fossil with gap 1.28 and R/R200 [0.7615941  0.20708148 0.22804098 0.37040058 0.0565076  0.09960289
#  0.04799042]
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 6
# -halo:  6
#  -central:  184931
#  -stellar mass:  11.899463
#  -r200:  688.69025
#  -m200:  13.542118
# 2.509765625
# Group 6 classified as fossil with gap 2.51 and R/R200 [0.09400053 0.13270469 0.05338612 0.11583238 0.4721775  0.05365064
#  0.07787044]
# 2.509765625
# Group 6 classified as fossil with gap 2.51 and R/R200 [0.09400053 0.13270469 0.5026287  0.6539478  0.57279927 0.6577049
#  0.05338612 0.11583238 0.6426742  0.546416   0.4721775  0.05365064
#  0.7177104  0.07787044]
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 7
# -halo:  7
#  -central:  198182
#  -stellar mass:  12.121235
#  -r200:  680.3034
#  -m200:  13.526118
# 5.26948356628418
# Group 7 classified as fossil with gap 5.27 and R/R200 [0.28213534]
# 3.8864269256591797
# Group 7 classified as fossil with gap 3.89 and R/R200 [0.62000376 0.5216472  0.5199877  0.28213534 0.72008044]
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 8
# -halo:  8
#  -central:  208811
#  -stellar mass:  11.908348
#  -r200:  637.6091
#  -m200:  13.44174
# 3.892091751098633
# Group 8 classified as fossil with gap 3.89 and R/R200 [0.45374095 0.30575576 0.28238732 0.20906211 0.30089483]
# 3.892091751098633
# Group 8 classified as fossil with gap 3.89 and R/R200 [0.45374095 0.9243732  0.30575576 0.9598138  0.28238732 0.20906211
#  0.6381976  0.87448514 0.30089483]
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 9
# -halo:  9
#  -central:  220595
#  -stellar mass:  11.906181
#  -r200:  675.70386
#  -m200:  13.517338
# 3.728221893310547
# Group 9 classified as fossil with gap 3.73 and R/R200 [0.34200913 0.0906348  0.14252579 0.19063918 0.38902518 0.19359504
#  0.17706114 0.03210445]
# 1.6784400939941406
# Group 9 classified as non-fossil with gap 1.68 and R/R200 [0.50588906 0.6356431  0.55886453 0.9100876  0.7030891  0.34200913
#  0.6856727  0.0906348  0.14252579 0.19063918 0.38902518 0.19359504
#  0.17706114 0.03210445]
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 10
# -halo:  10
#  -central:  229933
#  -stellar mass:  11.914373
#  -r200:  609.7404
#  -m200:  13.383478
# 4.177158355712891
# Group 10 classified as fossil with gap 4.18 and R/R200 [0.44679052 0.16793163 0.06522802]
# 4.177158355712891
# Group 10 classified as fossil with gap 4.18 and R/R200 [0.44679052 0.65354574 0.79881597 0.16793163 0.06522802]
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
#

# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 19
# -halo:  19
#  -central:  307485
#  -stellar mass:  11.318757
#  -r200:  515.606
#  -m200:  13.165004
# 0.2895164489746094
# Group 19 classified as non-fossil with gap 0.29 and R/R200 [0.24883702 0.42861554]
# 0.9860458374023438
# Group 19 classified as non-fossil with gap 0.99 and R/R200 [0.77508044 0.24883702 0.7713295  0.42861554 0.7017804  0.8291007 ]
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 20
# -halo:  20
#  -central:  313692
#  -stellar mass:  11.697162
#  -r200:  512.92163
#  -m200:  13.158189
# 2.8870067596435547
# Group 20 classified as fossil with gap 2.89 and R/R200 [0.4223611]
# 2.8125953674316406
# Group 20 classified as fossil with gap 2.81 and R/R200 [0.88501304 0.4223611  0.8686912  0.6882101  0.9222533 ]
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 21
# -halo:  21
#  -central:  319730
#  -stellar mass:  11.819218
#  -r200:  510.01
#  -m200:  13.150792
# 5.855234146118164
# Group 21 classified as fossil with gap 5.86 and R/R200 [0.09873638]
# 3.5399227142333984
# Group 21 classified as fossil with gap 3.54 and R/R200 [0.8634032  0.8405712  0.09873638]
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 22
# -halo:  22
#  -central:  324123
#  -stellar mass:  11.572527
#  -r200:  499.42688
#  -m200:  13.12343
# 3.4282493591308594
# Group 22 classified as fossil with gap 3.43 and R/R200 [0.2491993  0.41545048 0.0326341  0.3814608 ]
# 0.6560382843017578
# Group 22 classified as non-fossil with gap 0.66 and R/R200 [0.64299387 0.9592179  0.2491993  0.41545048 0.0326341  0.3814608 ]
# len(valid_halos) = 10247012
# valid_halos.dtype = bool
# len(halos["HaloID"][valid_halos]) = 24
# 23
# -halo:  23
#  -central:  329508
#  -stellar mass:  11.684048
#  -r200:  466.94867
#  -m200:  13.035825
# El grupo 23 solo tiene una galaxia central dentro de 0.5 R200
# 3.2039756774902344
# Group 23 classified as fossil with gap 3.20 and R/R200 [0.7555506]

# %%
central_pos
# Out:
# array([10930.857, 29852.062, 32545.31 ], dtype=float32)

# %%
output_file = 'fossil_cat_TNG50.hdf5'

with h5py.File(output_file, 'w') as f:
    
    f.attrs['description'] = 'Catalog of fossil groups in TNG50'
    f.attrs['snapshot'] = P.SNAP
    f.attrs['gap_threshold'] = P.GAP_THRESHOLD
    f.attrs['mass_cut_log10'] = 9.5
    f.attrs['radii_R200'] = [0.5, 1.0]
    
    for r_label, F_data, NF_data, iso_data in zip(
            ['0.5R200', '1.0R200'],
            [(F05R200, F05R200_deltamags, F05_distance, F05_mass, F05_radius, F05_sats),
            (F1R200,   F1R200_deltamags,   F1_distance,  F1_mass,  F1_radius,  F1_sats)],
            [(NF05R200, NF05R200_deltamags, NF05_distance, NF05_mass, NF05_radius, NF05_sats),
            (NF1R200,   NF1R200_deltamags,   NF1_distance,  NF1_mass,  NF1_radius,  NF1_sats)],
            [(iso_fossil_05, iso_F05_mass, iso_F05_radius), 
             (iso_fossil_1,  iso_F1_mass,  iso_F1_radius)]):
        r_group = f.create_group(r_label)
        spi.save_category(r_group.create_group('Fossil'), *F_data)
        spi.save_category(r_group.create_group('NonFossil'), *NF_data)
        spi.save_isolated(r_group.create_group('Isolated'), *iso_data)
        
print(f'Catalog saved to {output_file}')
# Out:
# Catalog saved to fossil_cat_TNG50.hdf5
